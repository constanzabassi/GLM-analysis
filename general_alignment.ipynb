# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

base_dir = 'C:\\Code\\Github\\States_pupil_analysis\\'
os.chdir(base_dir)  # Change the working directory to the current file directory  

# Import your helper functions
from helper_functions.data_loader import DataLoader  # Import the DataLoader class
from helper_functions.data_analyzer import DataAnalyzer
from helper_functions.data_aligner import DataAligner
from helper_functions.data_pipeline import DataPipeline
from helper_functions.data_plotter import Plotter

# %%
# Your datasets list
datasets = [
    ("HA1-00", "2023-06-27", 'V:'),

]

# datasets = [("HA1-00", "2023-06-27", 'V:'),("HA1-00", "2023-06-29", 'V:')]
# Define the base directory for datasets
base_dir = 'C:\\Code\\Github\\States_pupil_analysis\\datasets\\'

# Now run your pipeline
pipeline = DataPipeline()

# Load the data from the datasets list
data_loaders, celltype_info = pipeline.load_data(datasets,load_celltypes=1)
# Out:
# Loading data for: Animal: HA1-00, Date: 2023-06-27, Server: V:

# %%
good_trials_all = []
alignment = {}
alignment['type']  = 'pre'  
for data_loader, (key, info) in zip(data_loaders, celltype_info.items()):
    animalID, date = key
    server_info = info  # This will be the celltype information for the corresponding dataset

    celltypes = celltype_info[animalID, date]['neuron_groups']

    # Load the data using the data loader
    pupil_data = data_loader.load_pupil_data()
    neural_data, good_trials, trial_info, movement_in_imaging, frame_id_events, file_num, velocity_data, imaging = data_loader.load_neural_data(neural_data_type='dff')
    good_trials_all.append(good_trials)
    # latent_states = data_loader.load_latent_states() #could be other things like correct/incorrect or performance metric

    # Align the data
    imaging_frame_lengths = data_loader.load_alignment_data()
    global_frame_ids = data_loader.align_frames_to_session(file_num, frame_id_events, imaging_frame_lengths)

    # Define movement frames by trial
    movement_frames = {}
    
    for trial in range(len(neural_data)):
        if trial in good_trials:
            movement_frames[trial] = {
                'maze_frames': movement_in_imaging[trial]['maze_frames'],
                'reward_frames': movement_in_imaging[trial]['reward_frames'],
                'iti_frames': movement_in_imaging[trial]['iti_frames']
            }
        else:
            movement_frames[trial] = None

    # Initialize the DataAligner with the new parameters
    aligner = DataAligner(neural_data, movement_frames, velocity_data, global_frame_ids, good_trials)

    # Align the data to the desired epoch (e.g., 'maze', 'reward', 'iti', or 'all')
    align_info, alignment_frames, left_padding, right_padding = aligner.find_align_info(imaging, 30, alternative_alignment=False) #neural (mean across cells), pupil, velocity, and neural_all (single cells)
    aligned_imaging, imaging_array, align_info, frames = aligner.align_behavior_data( imaging, align_info, alignment_frames, left_padding, right_padding, 
                       alignment = alignment, cell_ids=None)
# Out:
# W:/Connie/Analysis/HA1-00-2023-06-27/HA1-00-2023-06-27final_fit.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 37
#      34 aligner = DataAligner(neural_data, movement_frames, velocity_data, global_frame_ids, good_trials)
#      36 # Align the data to the desired epoch (e.g., 'maze', 'reward', 'iti', or 'all')
# ---> 37 align_info, alignment_frames, left_padding, right_padding = aligner.find_align_info(imaging, 30, alternative_alignment=False) #neural (mean across cells), pupil, velocity, and neural_all (single cells)
#      38 aligned_imaging, imaging_array, align_info, frames = aligner.align_behavior_data( imaging, align_info, alignment_frames, left_padding, right_padding,
#      39                    alignment = alignment, cell_ids=None)
#
# File C:\Code\Github\States_pupil_analysis\helper_functions\data_aligner.py:435, in DataAligner.find_align_info(self, imaging, turn_frames, alternative_alignment)
#     432     right_padding[event] = 30
#     434 elif event == 3:
# --> 435     alignment_frames[event,:] = [
#     436         trial['turn_frame'][0] - 1 if isinstance(trial['turn_frame'], list) else trial['turn_frame'] - 1
#     437         for trial in imaging_array
#     438     ]
#     439     left_padding[event] = 30 if not alternative_alignment else 90
#     440     right_padding[event] = 12 if not alternative_alignment else 60
#
# ValueError: setting an array element with a sequence. The requested array would exceed the maximum number of dimension of 1.

# %%
imaging_array = [imaging[i]['movement_in_imaging_time'][0][0] for i in good_trials]

# %%
[
trial['turn_frame'][0] - 1 if isinstance(trial['turn_frame'], list) else trial['turn_frame'] - 1
for trial in imaging_array
]
# Out:
# [array([[223]], dtype=uint8),
#  array([[221]], dtype=uint8),
#  array([[228]], dtype=uint8),
#  array([[235]], dtype=uint8),
#  array([[357]], dtype=uint16),
#  array([[631]], dtype=uint16),
#  array([[256]], dtype=uint16),
#  array([[282]], dtype=uint16),
#  array([[1292]], dtype=uint16),
#  array([[691]], dtype=uint16),
#  array([[232]], dtype=uint8),
#  array([[266]], dtype=uint16),
#  array([[237]], dtype=uint8),
#  array([[302]], dtype=uint16),
#  array([[272]], dtype=uint16),
#  array([[293]], dtype=uint16),
#  array([[354]], dtype=uint16),
#  array([[248]], dtype=uint8),
#  array([[245]], dtype=uint8),
#  array([[410]], dtype=uint16),
#  array([[255]], dtype=uint16),
#  array([[251]], dtype=uint8),
#  array([[243]], dtype=uint8),
#  array([[268]], dtype=uint16),
#  array([[241]], dtype=uint8),
#  array([[257]], dtype=uint16),
#  array([[276]], dtype=uint16),
#  array([[288]], dtype=uint16),
#  array([[281]], dtype=uint16),
#  array([[681]], dtype=uint16),
#  array([[244]], dtype=uint8),
#  array([[226]], dtype=uint8),
#  array([[223]], dtype=uint8),
#  array([[310]], dtype=uint16),
#  array([[254]], dtype=uint8),
#  array([[235]], dtype=uint8),
#  array([[240]], dtype=uint8),
#  array([[256]], dtype=uint16),
#  array([[285]], dtype=uint16),
#  array([[484]], dtype=uint16),
#  array([[248]], dtype=uint8),
#  array([[233]], dtype=uint8),
#  array([[372]], dtype=uint16),
#  array([[208]], dtype=uint8),
#  array([[278]], dtype=uint16),
#  array([[271]], dtype=uint16),
#  array([[213]], dtype=uint8),
#  array([[290]], dtype=uint16),
#  array([[233]], dtype=uint8),
#  array([[233]], dtype=uint8),
#  array([[234]], dtype=uint8),
#  array([[252]], dtype=uint8),
#  array([[265]], dtype=uint16),
#  array([[224]], dtype=uint8),
#  array([[281]], dtype=uint16),
#  array([[264]], dtype=uint16),
#  array([[522]], dtype=uint16),
#  array([[252]], dtype=uint8),
#  array([[239]], dtype=uint8),
#  array([[222]], dtype=uint8),
#  array([[228]], dtype=uint8),
#  array([[244]], dtype=uint8),
#  array([[255]], dtype=uint16),
#  array([[288]], dtype=uint16),
#  array([[237]], dtype=uint8),
#  array([[268]], dtype=uint16),
#  array([[273]], dtype=uint16),
#  array([[238]], dtype=uint8),
#  array([[301]], dtype=uint16),
#  array([[236]], dtype=uint8),
#  array([[300]], dtype=uint16),
#  array([[266]], dtype=uint16),
#  array([[278]], dtype=uint16),
#  array([[231]], dtype=uint8),
#  array([[305]], dtype=uint16),
#  array([[240]], dtype=uint8),
#  array([[275]], dtype=uint16),
#  array([[259]], dtype=uint16),
#  array([[304]], dtype=uint16),
#  array([[269]], dtype=uint16),
#  array([[270]], dtype=uint16),
#  array([[254]], dtype=uint8),
#  array([[359]], dtype=uint16),
#  array([[559]], dtype=uint16),
#  array([[237]], dtype=uint8),
#  array([[309]], dtype=uint16),
#  array([[255]], dtype=uint16),
#  array([[322]], dtype=uint16),
#  array([[303]], dtype=uint16),
#  array([[278]], dtype=uint16),
#  array([[657]], dtype=uint16),
#  array([[256]], dtype=uint16),
#  array([[233]], dtype=uint8),
#  array([[242]], dtype=uint8),
#  array([[266]], dtype=uint16),
#  array([[240]], dtype=uint8),
#  array([[265]], dtype=uint16),
#  array([[254]], dtype=uint8),
#  array([[247]], dtype=uint8),
#  array([[426]], dtype=uint16),
#  array([[341]], dtype=uint16),
#  array([[257]], dtype=uint16),
#  array([[234]], dtype=uint8),
#  array([[284]], dtype=uint16),
#  array([[332]], dtype=uint16),
#  array([[572]], dtype=uint16),
#  array([[343]], dtype=uint16),
#  array([[235]], dtype=uint8),
#  array([[267]], dtype=uint16),
#  array([[330]], dtype=uint16),
#  array([[254]], dtype=uint8),
#  array([[291]], dtype=uint16),
#  array([[284]], dtype=uint16),
#  array([[233]], dtype=uint8),
#  array([[276]], dtype=uint16),
#  array([[395]], dtype=uint16),
#  array([[514]], dtype=uint16),
#  array([[277]], dtype=uint16),
#  array([[289]], dtype=uint16),
#  array([[272]], dtype=uint16),
#  array([[273]], dtype=uint16),
#  array([[259]], dtype=uint16),
#  array([[329]], dtype=uint16),
#  array([[222]], dtype=uint8),
#  array([[259]], dtype=uint16),
#  array([[418]], dtype=uint16),
#  array([[235]], dtype=uint8),
#  array([[276]], dtype=uint16),
#  array([[509]], dtype=uint16),
#  array([[278]], dtype=uint16),
#  array([[273]], dtype=uint16),
#  array([[244]], dtype=uint8),
#  array([[328]], dtype=uint16),
#  array([[261]], dtype=uint16),
#  array([[261]], dtype=uint16),
#  array([[283]], dtype=uint16),
#  array([[262]], dtype=uint16),
#  array([[429]], dtype=uint16),
#  array([[311]], dtype=uint16),
#  array([[302]], dtype=uint16),
#  array([[312]], dtype=uint16),
#  array([[327]], dtype=uint16),
#  array([[290]], dtype=uint16),
#  array([[253]], dtype=uint8),
#  array([[287]], dtype=uint16),
#  array([[281]], dtype=uint16),
#  array([[327]], dtype=uint16),
#  array([[294]], dtype=uint16),
#  array([[266]], dtype=uint16),
#  array([[598]], dtype=uint16),
#  array([[270]], dtype=uint16),
#  array([[304]], dtype=uint16),
#  array([[270]], dtype=uint16),
#  array([[302]], dtype=uint16),
#  array([[400]], dtype=uint16),
#  array([[272]], dtype=uint16),
#  array([[318]], dtype=uint16),
#  array([[423]], dtype=uint16),
#  array([[259]], dtype=uint16),
#  array([[259]], dtype=uint16),
#  array([[333]], dtype=uint16),
#  array([[277]], dtype=uint16),
#  array([[265]], dtype=uint16),
#  array([[331]], dtype=uint16),
#  array([[276]], dtype=uint16),
#  array([[265]], dtype=uint16),
#  array([[290]], dtype=uint16),
#  array([[348]], dtype=uint16),
#  array([[323]], dtype=uint16)]

# %%
[trial['turn_frame'][0] for trial in imaging_array]
# Out:
# [array([224], dtype=uint8),
#  array([222], dtype=uint8),
#  array([229], dtype=uint8),
#  array([236], dtype=uint8),
#  array([358], dtype=uint16),
#  array([632], dtype=uint16),
#  array([257], dtype=uint16),
#  array([283], dtype=uint16),
#  array([1293], dtype=uint16),
#  array([692], dtype=uint16),
#  array([233], dtype=uint8),
#  array([267], dtype=uint16),
#  array([238], dtype=uint8),
#  array([303], dtype=uint16),
#  array([273], dtype=uint16),
#  array([294], dtype=uint16),
#  array([355], dtype=uint16),
#  array([249], dtype=uint8),
#  array([246], dtype=uint8),
#  array([411], dtype=uint16),
#  array([256], dtype=uint16),
#  array([252], dtype=uint8),
#  array([244], dtype=uint8),
#  array([269], dtype=uint16),
#  array([242], dtype=uint8),
#  array([258], dtype=uint16),
#  array([277], dtype=uint16),
#  array([289], dtype=uint16),
#  array([282], dtype=uint16),
#  array([682], dtype=uint16),
#  array([245], dtype=uint8),
#  array([227], dtype=uint8),
#  array([224], dtype=uint8),
#  array([311], dtype=uint16),
#  array([255], dtype=uint8),
#  array([236], dtype=uint8),
#  array([241], dtype=uint8),
#  array([257], dtype=uint16),
#  array([286], dtype=uint16),
#  array([485], dtype=uint16),
#  array([249], dtype=uint8),
#  array([234], dtype=uint8),
#  array([373], dtype=uint16),
#  array([209], dtype=uint8),
#  array([279], dtype=uint16),
#  array([272], dtype=uint16),
#  array([214], dtype=uint8),
#  array([291], dtype=uint16),
#  array([234], dtype=uint8),
#  array([234], dtype=uint8),
#  array([235], dtype=uint8),
#  array([253], dtype=uint8),
#  array([266], dtype=uint16),
#  array([225], dtype=uint8),
#  array([282], dtype=uint16),
#  array([265], dtype=uint16),
#  array([523], dtype=uint16),
#  array([253], dtype=uint8),
#  array([240], dtype=uint8),
#  array([223], dtype=uint8),
#  array([229], dtype=uint8),
#  array([245], dtype=uint8),
#  array([256], dtype=uint16),
#  array([289], dtype=uint16),
#  array([238], dtype=uint8),
#  array([269], dtype=uint16),
#  array([274], dtype=uint16),
#  array([239], dtype=uint8),
#  array([302], dtype=uint16),
#  array([237], dtype=uint8),
#  array([301], dtype=uint16),
#  array([267], dtype=uint16),
#  array([279], dtype=uint16),
#  array([232], dtype=uint8),
#  array([306], dtype=uint16),
#  array([241], dtype=uint8),
#  array([276], dtype=uint16),
#  array([260], dtype=uint16),
#  array([305], dtype=uint16),
#  array([270], dtype=uint16),
#  array([271], dtype=uint16),
#  array([255], dtype=uint8),
#  array([360], dtype=uint16),
#  array([560], dtype=uint16),
#  array([238], dtype=uint8),
#  array([310], dtype=uint16),
#  array([256], dtype=uint16),
#  array([323], dtype=uint16),
#  array([304], dtype=uint16),
#  array([279], dtype=uint16),
#  array([658], dtype=uint16),
#  array([257], dtype=uint16),
#  array([234], dtype=uint8),
#  array([243], dtype=uint8),
#  array([267], dtype=uint16),
#  array([241], dtype=uint8),
#  array([266], dtype=uint16),
#  array([255], dtype=uint8),
#  array([248], dtype=uint8),
#  array([427], dtype=uint16),
#  array([342], dtype=uint16),
#  array([258], dtype=uint16),
#  array([235], dtype=uint8),
#  array([285], dtype=uint16),
#  array([333], dtype=uint16),
#  array([573], dtype=uint16),
#  array([344], dtype=uint16),
#  array([236], dtype=uint8),
#  array([268], dtype=uint16),
#  array([331], dtype=uint16),
#  array([255], dtype=uint8),
#  array([292], dtype=uint16),
#  array([285], dtype=uint16),
#  array([234], dtype=uint8),
#  array([277], dtype=uint16),
#  array([396], dtype=uint16),
#  array([515], dtype=uint16),
#  array([278], dtype=uint16),
#  array([290], dtype=uint16),
#  array([273], dtype=uint16),
#  array([274], dtype=uint16),
#  array([260], dtype=uint16),
#  array([330], dtype=uint16),
#  array([223], dtype=uint8),
#  array([260], dtype=uint16),
#  array([419], dtype=uint16),
#  array([236], dtype=uint8),
#  array([277], dtype=uint16),
#  array([510], dtype=uint16),
#  array([279], dtype=uint16),
#  array([274], dtype=uint16),
#  array([245], dtype=uint8),
#  array([329], dtype=uint16),
#  array([262], dtype=uint16),
#  array([262], dtype=uint16),
#  array([284], dtype=uint16),
#  array([263], dtype=uint16),
#  array([430], dtype=uint16),
#  array([312], dtype=uint16),
#  array([303], dtype=uint16),
#  array([313], dtype=uint16),
#  array([328], dtype=uint16),
#  array([291], dtype=uint16),
#  array([254], dtype=uint8),
#  array([288], dtype=uint16),
#  array([282], dtype=uint16),
#  array([328], dtype=uint16),
#  array([295], dtype=uint16),
#  array([267], dtype=uint16),
#  array([599], dtype=uint16),
#  array([271], dtype=uint16),
#  array([305], dtype=uint16),
#  array([271], dtype=uint16),
#  array([303], dtype=uint16),
#  array([401], dtype=uint16),
#  array([273], dtype=uint16),
#  array([319], dtype=uint16),
#  array([424], dtype=uint16),
#  array([260], dtype=uint16),
#  array([260], dtype=uint16),
#  array([334], dtype=uint16),
#  array([278], dtype=uint16),
#  array([266], dtype=uint16),
#  array([332], dtype=uint16),
#  array([277], dtype=uint16),
#  array([266], dtype=uint16),
#  array([291], dtype=uint16),
#  array([349], dtype=uint16),
#  array([324], dtype=uint16)]
